# %%
import sys
import random
import pandas as pd 
from collections import defaultdict
# third party programs
sys.path.append("../")
import simple_path
from simple_path import StringDB, parse_input

# %%
db = StringDB("../Data/STRING.txt")
StringDB_df = db.to_pandas()
data_input = parse_input("../input/Input.gmt.txt")

# %%
# load in the the locus and build a function of 5000 random sub networks within the locus and def generate_random_network(n_networks: int) -> list:
def generate_random_subnetworks(n_networks):
	""" Generates random subnetworks where each gene is selected per locus_name

	Arguments:
	---------
	n_networks : int
		number of subnetworks to generate

	Results:
	-------
	list 
		list of list where a each list contains  genes that make up the random sub
		network.

	limitation
	----------
	algortihm is O(N^2) when generating. Therefore increasing the number of generated
	random sublist will make it larger
	""" 
	networks = []
	for idx in range(n_networks):
		sub_network = []
		for gene_list in data_input.values():
			gene = random.choice(gene_list)
			sub_network.append(gene)
		networks.append(sub_network)
	return networks


def get_connected_genes(string_df):
	""" 
	["description later"]
	"""	
	# generating a set of all known genes within string database
	# -- both columns genes together and converts it into a set (removes all repeats)

	# grouping data based on gene name	
	grouped_df = string_df.groupby(by=["gene1"])
	connected_genes = defaultdict(None)
	for gene, gene_df in grouped_df:
		conn_genes_arr = gene_df["gene2"].values.tolist()
		connected_genes[gene] = conn_genes_arr

	return connected_genes


def get_gene_counts(connected_genes_data, sort=True):
	"""
	
	"""
	gene_counts = defaultdict(None)
	for gene, connected_genes in connected_genes_data.items():
		gene_counts[gene] = len(connected_genes)

	if sort is True:
		gene_counts = {k: v for k, v in sorted(gene_counts.items(), key=lambda item: item[1])}

	return gene_counts	



def generate_cofunctional_network(string_db):
    """ counts all the edges attached to a gene 
	
	requires binned data 
	selecting cofunctional network requires bind data in order to select random genes from a bin
	"""
    # create a set of all known genes 
    # col1 = strign_db[]
    # for loop of set of genes and query them into pandas df to find all edges connected to that gene 
		#

# %%
connected_genes = get_connected_genes(StringDB_df)
gene_counts = get_gene_counts(connected_genes)
# Out:
# 1

# %%
key_list = list(gene_counts.keys())
val_list = list(gene_counts.values())

position = val_list.index(10114)
key_list[position]
# Out:
# 'UBC'

# %%
gene_counts
# Out:
# {'AAED1': 1,
#  'AC002472.13': 1,
#  'AC004017.1': 1,
#  'AC012313.1': 1,
#  'AC074389.6': 1,
#  'AC096677.1': 1,
#  'AC114772.1': 1,
#  'AC142381.1': 1,
#  'ACPL2': 1,
#  'ACPT': 1,
#  'ACYP1': 1,
#  'ADAM28': 1,
#  'ADAMTS13': 1,
#  'ADAMTS15': 1,
#  'ADAMTS17': 1,
#  'ADAMTS6': 1,
#  'ADAMTS9': 1,
#  'ADAMTSL2': 1,
#  'ADTRP': 1,
#  'AIM1L': 1,
#  'AL035252.1': 1,
#  'AL049836.1': 1,
#  'AL117190.3': 1,
#  'AL161784.1': 1,
#  'AL353791.1': 1,
#  'ALKBH6': 1,
#  'ALPK2': 1,
#  'AMICA1': 1,
#  'ANGPTL5': 1,
#  'ANGPTL6': 1,
#  'ANKAR': 1,
#  'ANKRD34A': 1,
#  'ANO2': 1,
#  'ANO9': 1,
#  'ANXA2R': 1,
#  'ANXA9': 1,
#  'AOC2': 1,
#  'APLNR': 1,
#  'APOBEC4': 1,
#  'AQP11': 1,
#  'ARHGAP22': 1,
#  'ARL6IP6': 1,
#  'ARMC10': 1,
#  'ARMCX2': 1,
#  'ART1': 1,
#  'ART4': 1,
#  'ASAH2': 1,
#  'ASAH2B': 1,
#  'ASAH2C': 1,
#  'ASB16-AS1': 1,
#  'ASIC5': 1,
#  'ASTN1': 1,
#  'ATAT1': 1,
#  'ATXN7L3B': 1,
#  'AUNIP': 1,
#  'AVPR2': 1,
#  'B3GALNT1': 1,
#  'B3GALNT2': 1,
#  'B3GALT2': 1,
#  'B3GAT1': 1,
#  'B3GNT3': 1,
#  'B3GNT5': 1,
#  'B3GNT9': 1,
#  'B4GALNT1': 1,
#  'BAALC': 1,
#  'BAI3': 1,
#  'BCAS4': 1,
#  'BCMO1': 1,
#  'BEAN1': 1,
#  'BEND2': 1,
#  'BEX4': 1,
#  'BIVM': 1,
#  'BNC1': 1,
#  'BOD1': 1,
#  'BPIFA2': 1,
#  'BPY2B': 1,
#  'BRICD5': 1,
#  'BTBD7': 1,
#  'BTBD8': 1,
#  'BTN3A2': 1,
#  'BTNL8': 1,
#  'BVES': 1,
#  'C10orf114': 1,
#  'C10orf116': 1,
#  'C10orf32': 1,
#  'C10orf76': 1,
#  'C10orf82': 1,
#  'C10orf95': 1,
#  'C11orf70': 1,
#  'C11orf80': 1,
#  'C11orf9': 1,
#  'C12orf40': 1,
#  'C12orf55': 1,
#  'C12orf69': 1,
#  'C12orf73': 1,
#  'C12orf75': 1,
#  'C15orf38-AP3S2': 1,
#  'C15orf57': 1,
#  'C15orf59': 1,
#  'C16orf11': 1,
#  'C16orf47': 1,
#  'C16orf54': 1,
#  'C16orf58': 1,
#  'C17orf75': 1,
#  'C17orf82': 1,
#  'C17orf96': 1,
#  'C18orf21': 1,
#  'C18orf63': 1,
#  'C19orf12': 1,
#  'C19orf21': 1,
#  'C19orf26': 1,
#  'C19orf33': 1,
#  'C19orf53': 1,
#  'C19orf54': 1,
#  'C19orf55': 1,
#  'C19orf68': 1,
#  'C19orf73': 1,
#  'C19orf77': 1,
#  'C19orf80': 1,
#  'C1QL1': 1,
#  'C1QL3': 1,
#  'C1QTNF5': 1,
#  'C1QTNF6': 1,
#  'C1QTNF7': 1,
#  'C1QTNF9B-AS1': 1,
#  'C1RL': 1,
#  'C1orf105': 1,
#  'C1orf110': 1,
#  'C1orf112': 1,
#  'C1orf122': 1,
#  'C1orf131': 1,
#  'C1orf168': 1,
#  'C1orf173': 1,
#  'C1orf43': 1,
#  'C1orf61': 1,
#  'C1orf68': 1,
#  'C1orf85': 1,
#  'C20orf141': 1,
#  'C20orf26': 1,
#  'C22orf29': 1,
#  'C2orf27B': 1,
#  'C2orf40': 1,
#  'C2orf42': 1,
#  'C2orf50': 1,
#  'C2orf57': 1,
#  'C2orf68': 1,
#  'C2orf74': 1,
#  'C3orf33': 1,
#  'C4B': 1,
#  'C4orf21': 1,
#  'C4orf22': 1,
#  'C4orf26': 1,
#  'C4orf51': 1,
#  'C5orf20': 1,
#  'C5orf34': 1,
#  'C5orf60': 1,
#  'C6orf201': 1,
#  'C6orf47': 1,
#  'C6orf48': 1,
#  'C6orf62': 1,
#  'C6orf89': 1,
#  'C7orf13': 1,
#  'C7orf29': 1,
#  'C7orf31': 1,
#  'C7orf34': 1,
#  'C8orf40': 1,
#  'C8orf47': 1,
#  'C8orf48': 1,
#  'C8orf73': 1,
#  'C8orf76': 1,
#  'C9orf116': 1,
#  'C9orf142': 1,
#  'C9orf171': 1,
#  'C9orf174': 1,
#  'C9orf40': 1,
#  'C9orf89': 1,
#  'CA5A': 1,
#  'CA5B': 1,
#  'CA7': 1,
#  'CAAP1': 1,
#  'CABYR': 1,
#  'CACNA2D3': 1,
#  'CACNG3': 1,
#  'CACNG5': 1,
#  'CACNG7': 1,
#  'CAMTA1': 1,
#  'CASC1': 1,
#  'CASC4': 1,
#  'CATSPER2': 1,
#  'CATSPER3': 1,
#  'CATSPERD': 1,
#  'CATSPERG': 1,
#  'CBLN1': 1,
#  'CBLN2': 1,
#  'CC2D2A': 1,
#  'CCDC108': 1,
#  'CCDC109B': 1,
#  'CCDC110': 1,
#  'CCDC126': 1,
#  'CCDC127': 1,
#  'CCDC132': 1,
#  'CCDC135': 1,
#  'CCDC144A': 1,
#  'CCDC15': 1,
#  'CCDC159': 1,
#  'CCDC164': 1,
#  'CCDC169-SOHLH2': 1,
#  'CCDC170': 1,
#  'CCDC18': 1,
#  'CCDC34': 1,
#  'CCDC37': 1,
#  'CCDC41': 1,
#  'CCDC51': 1,
#  'CCDC71L': 1,
#  'CCDC81': 1,
#  'CCPG1': 1,
#  'CCR9': 1,
#  'CD200R1': 1,
#  'CD207': 1,
#  'CD300E': 1,
#  'CD300LD': 1,
#  'CD52': 1,
#  'CD5L': 1,
#  'CD96': 1,
#  'CDPF1': 1,
#  'CDR1': 1,
#  'CDRT4': 1,
#  'CECR6': 1,
#  'CEP112': 1,
#  'CEP128': 1,
#  'CEP95': 1,
#  'CER1': 1,
#  'CGB5': 1,
#  'CGB7': 1,
#  'CHIC1': 1,
#  'CHODL': 1,
#  'CHST10': 1,
#  'CHST7': 1,
#  'CHST9': 1,
#  'CHURC1': 1,
#  'CKLF-CMTM1': 1,
#  'CLCA2': 1,
#  'CLCC1': 1,
#  'CLDN10': 1,
#  'CLDN15': 1,
#  'CLDN6': 1,
#  'CLDND1': 1,
#  'CLEC17A': 1,
#  'CLEC18A': 1,
#  'CLEC18C': 1,
#  'CLEC1A': 1,
#  'CLEC1B': 1,
#  'CLEC2B': 1,
#  'CLEC4F': 1,
#  'CLEC5A': 1,
#  'CLMP': 1,
#  'CLRN3': 1,
#  'CMTM1': 1,
#  'CMTM2': 1,
#  'CMTM7': 1,
#  'CMTM8': 1,
#  'CNPY3': 1,
#  'CNRIP1': 1,
#  'CNTLN': 1,
#  'COL6A5': 1,
#  'COX20': 1,
#  'CPED1': 1,
#  'CPNE5': 1,
#  'CPNE6': 1,
#  'CPNE9': 1,
#  'CPXM2': 1,
#  'CPZ': 1,
#  'CRHBP': 1,
#  'CRISPLD2': 1,
#  'CRYGA': 1,
#  'CSMD3': 1,
#  'CSPG5': 1,
#  'CSRNP3': 1,
#  'CST5': 1,
#  'CTAGE8': 1,
#  'CTB-102L5.4': 1,
#  'CTXN1': 1,
#  'CUZD1': 1,
#  'CXCR6': 1,
#  'CXorf38': 1,
#  'CXorf69': 1,
#  'CYSLTR1': 1,
#  'DACT3': 1,
#  'DAOA': 1,
#  'DCAF8L2': 1,
#  'DCT': 1,
#  'DDAH2': 1,
#  'DEFA1B': 1,
#  'DEFA6': 1,
#  'DEFB103A': 1,
#  'DEFB121': 1,
#  'DEFB127': 1,
#  'DEFB132': 1,
#  'DEFB4B': 1,
#  'DEGS2': 1,
#  'DENND4B': 1,
#  'DEXI': 1,
#  'DKK3': 1,
#  'DNAAF1': 1,
#  'DNAAF3': 1,
#  'DNAH14': 1,
#  'DOK7': 1,
#  'DPPA3': 1,
#  'DRAM2': 1,
#  'DSCR3': 1,
#  'DSCR8': 1,
#  'DTWD1': 1,
#  'EDDM3B': 1,
#  'EFCAB12': 1,
#  'EFHA2': 1,
#  'EGFL6': 1,
#  'ELMOD1': 1,
#  'EMB': 1,
#  'EMILIN2': 1,
#  'EML5': 1,
#  'EMP2': 1,
#  'EPG5': 1,
#  'EPPIN': 1,
#  'EPPIN-WFDC6': 1,
#  'ERV3-1': 1,
#  'ETAA1': 1,
#  'EVA1A': 1,
#  'EVA1B': 1,
#  'EVC2': 1,
#  'FABP12': 1,
#  'FABP9': 1,
#  'FAM102B': 1,
#  'FAM104A': 1,
#  'FAM104B': 1,
#  'FAM109B': 1,
#  'FAM111A': 1,
#  'FAM120AOS': 1,
#  'FAM123A': 1,
#  'FAM126B': 1,
#  'FAM131A': 1,
#  'FAM134A': 1,
#  'FAM135A': 1,
#  'FAM13A': 1,
#  'FAM153A': 1,
#  'FAM165A': 1,
#  'FAM167A': 1,
#  'FAM169A': 1,
#  'FAM171A1': 1,
#  'FAM174A': 1,
#  'FAM184B': 1,
#  'FAM190A': 1,
#  'FAM193A': 1,
#  'FAM195A': 1,
#  'FAM195B': 1,
#  'FAM19A1': 1,
#  'FAM19A4': 1,
#  'FAM200A': 1,
#  'FAM204A': 1,
#  'FAM20C': 1,
#  'FAM210B': 1,
#  'FAM212A': 1,
#  'FAM212B': 1,
#  'FAM213A': 1,
#  'FAM216A': 1,
#  'FAM217B': 1,
#  'FAM218A': 1,
#  'FAM219B': 1,
#  'FAM21D': 1,
#  'FAM222A': 1,
#  'FAM222B': 1,
#  'FAM22A': 1,
#  'FAM22B': 1,
#  'FAM26E': 1,
#  'FAM35A': 1,
#  'FAM3B': 1,
#  'FAM43B': 1,
#  'FAM69A': 1,
#  'FAM73A': 1,
#  'FAM78A': 1,
#  'FAM81A': 1,
#  'FAM81B': 1,
#  'FAM83C': 1,
#  'FAM84A': 1,
#  'FAM90A26P': 1,
#  'FAM9A': 1,
#  'FAM9C': 1,
#  'FCRLB': 1,
#  'FER1L6': 1,
#  'FGD4': 1,
#  'FIBCD1': 1,
#  'FKTN': 1,
#  'FLJ43860': 1,
#  'FNDC3A': 1,
#  'FNDC4': 1,
#  'FNDC5': 1,
#  'FNDC7': 1,
#  'FOLR2': 1,
#  'FOLR3': 1,
#  'FPGT': 1,
#  'FPR2': 1,
#  'FRAT2': 1,
#  'FSD1L': 1,
#  'FSIP1': 1,
#  'FSTL4': 1,
#  'FTSJD1': 1,
#  'FUK': 1,
#  'FUT10': 1,
#  'G0S2': 1,
#  'GABRA5': 1,
#  'GABRA6': 1,
#  'GABRG1': 1,
#  'GABRG3': 1,
#  'GAGE12I': 1,
#  'GAGE2D': 1,
#  'GAGE2E': 1,
#  'GAL3ST1': 1,
#  'GALNT11': 1,
#  'GALNT3': 1,
#  'GALNT8': 1,
#  'GALR1': 1,
#  'GALR3': 1,
#  'GATM': 1,
#  'GATSL1': 1,
#  'GATSL2': 1,
#  'GATSL3': 1,
#  'GCNT2': 1,
#  'GFRA3': 1,
#  'GFRAL': 1,
#  'GGACT': 1,
#  'GGNBP2': 1,
#  'GIMAP1': 1,
#  'GIMAP2': 1,
#  'GIMAP4': 1,
#  'GIMAP6': 1,
#  'GIMAP8': 1,
#  'GINM1': 1,
#  'GJA9': 1,
#  'GJD3': 1,
#  'GJD4': 1,
#  'GKN1': 1,
#  'GKN2': 1,
#  'GLT25D2': 1,
#  'GLT8D1': 1,
#  'GLT8D2': 1,
#  'GOLGA6L10': 1,
#  'GOLGA6L2': 1,
#  'GOLGA6L9': 1,
#  'GOLGA8A': 1,
#  'GOLGA8H': 1,
#  'GOLGA8J': 1,
#  'GPAT2': 1,
#  'GPATCH3': 1,
#  'GPER': 1,
#  'GPIHBP1': 1,
#  'GPR101': 1,
#  'GPR108': 1,
#  'GPR112': 1,
#  'GPR113': 1,
#  'GPR114': 1,
#  'GPR115': 1,
#  'GPR12': 1,
#  'GPR142': 1,
#  'GPR15': 1,
#  'GPR151': 1,
#  'GPR155': 1,
#  'GPR158': 1,
#  'GPR161': 1,
#  'GPR17': 1,
#  'GPR176': 1,
#  'GPR180': 1,
#  'GPR21': 1,
#  'GPR37L1': 1,
#  'GPR52': 1,
#  'GPR63': 1,
#  'GPR64': 1,
#  'GPR98': 1,
#  'GRM6': 1,
#  'GRPR': 1,
#  'GSG1L': 1,
#  'GSTA3': 1,
#  'GSTCD': 1,
#  'GTDC2': 1,
#  'GTF2IRD2B': 1,
#  'GUCA2A': 1,
#  'GUCA2B': 1,
#  'GYLTL1B': 1,
#  'HCFC1R1': 1,
#  'HEATR7A': 1,
#  'HEG1': 1,
#  'HERPUD2': 1,
#  'HES7': 1,
#  'HGSNAT': 1,
#  'HHLA3': 1,
#  'HRH3': 1,
#  'HTN3': 1,
#  'HTR1F': 1,
#  'HVCN1': 1,
#  'HYAL2': 1,
#  'ICOSLG': 1,
#  'IER5': 1,
#  'IER5L': 1,
#  'IFITM5': 1,
#  'IFNA16': 1,
#  'IFNA4': 1,
#  'IFNA5': 1,
#  'IFNE': 1,
#  'IFT46': 1,
#  'IGLON5': 1,
#  'IGSF21': 1,
#  'IGSF9': 1,
#  'IL11RA': 1,
#  'IL13RA2': 1,
#  'IL17RC': 1,
#  'IL17RE': 1,
#  'IL19': 1,
#  'IL1F10': 1,
#  'IL1RAPL2': 1,
#  'IL1RL2': 1,
#  'IL28B': 1,
#  'IL29': 1,
#  'IL36B': 1,
#  'IL9': 1,
#  'ILDR2': 1,
#  'IMPG1': 1,
#  'INMT': 1,
#  'INTU': 1,
#  'IPMK': 1,
#  'IQCF2': 1,
#  'IQCF5': 1,
#  'IQCG': 1,
#  'IQCJ': 1,
#  'IQCK': 1,
#  'IRGQ': 1,
#  'ITFG2': 1,
#  'ITFG3': 1,
#  'ITPKC': 1,
#  'JSRP1': 1,
#  'KANSL1L': 1,
#  'KCNMB2': 1,
#  'KCTD16': 1,
#  'KCTD21': 1,
#  'KHNYN': 1,
#  'KIAA0754': 1,
#  'KIAA0895': 1,
#  'KIAA1211': 1,
#  'KIAA1328': 1,
#  'KIAA1407': 1,
#  'KIAA1430': 1,
#  'KIAA1586': 1,
#  'KIAA1614': 1,
#  'KIAA1841': 1,
#  'KIAA2018': 1,
#  'KIR2DL1': 1,
#  'KIR3DL2': 1,
#  'KLRF1': 1,
#  'KREMEN1': 1,
#  'KRT25': 1,
#  'KRTAP13-3': 1,
#  'KRTAP16-1': 1,
#  'KRTAP3-2': 1,
#  'KRTAP5-1': 1,
#  'KRTCAP3': 1,
#  'LARGE': 1,
#  'LARP6': 1,
#  'LAYN': 1,
#  'LBH': 1,
#  'LCE3A': 1,
#  'LDLRAD3': 1,
#  'LEAP2': 1,
#  'LENG1': 1,
#  'LEPREL2': 1,
#  'LGI4': 1,
#  'LHFPL2': 1,
#  'LIM2': 1,
#  'LMTK3': 1,
#  'LOXHD1': 1,
#  'LPAR3': 1,
#  'LPPR3': 1,
#  'LPPR4': 1,
#  'LRP11': 1,
#  'LRRC25': 1,
#  'LRRC27': 1,
#  'LRRC34': 1,
#  'LRRC71': 1,
#  'LRRN4CL': 1,
#  'LUZP2': 1,
#  'LY6K': 1,
#  'LYNX1': 1,
#  'LYPD2': 1,
#  'LYPD4': 1,
#  'LYPD6B': 1,
#  'LYRM1': 1,
#  'LYSMD4': 1,
#  'MAMSTR': 1,
#  'MARVELD1': 1,
#  'MARVELD3': 1,
#  'MAS1': 1,
#  'MB21D2': 1,
#  'MCHR2': 1,
#  'MCIN': 1,
#  'MCTP2': 1,
#  'MDM1': 1,
#  'MEGF8': 1,
#  'MEI1': 1,
#  'MEIOB': 1,
#  'MFAP3': 1,
#  'MFAP3L': 1,
#  'MFSD12': 1,
#  'MGARP': 1,
#  'MGAT1': 1,
#  'MLIP': 1,
#  'MLN': 1,
#  'MMEL1': 1,
#  'MMP20': 1,
#  'MMP23B': 1,
#  'MMP27': 1,
#  'MMRN2': 1,
#  'MN1': 1,
#  'MORC1': 1,
#  'MOSPD1': 1,
#  'MPPED1': 1,
#  'MPZL3': 1,
#  'MRC1': 1,
#  'MREG': 1,
#  'MRGPRX2': 1,
#  'MS4A7': 1,
#  'MS4A8B': 1,
#  'MSANTD1': 1,
#  'MSANTD2': 1,
#  'MT1E': 1,
#  'MTRNR2L2': 1,
#  'MUCL1': 1,
#  'MUM1L1': 1,
#  'MURC': 1,
#  'MUSTN1': 1,
#  'MYEOV': 1,
#  'NAT2': 1,
#  'NBPF10': 1,
#  'NBPF12': 1,
#  'NBPF14': 1,
#  'NBPF16': 1,
#  'NBPF24': 1,
#  'NBPF9': 1,
#  'NCR2': 1,
#  'NEIL3': 1,
#  'NEURL2': 1,
#  'NINJ1': 1,
#  'NIPAL4': 1,
#  'NKX1-1': 1,
#  'NLRP11': 1,
#  'NLRP13': 1,
#  'NLRP14': 1,
#  'NLRP5': 1,
#  'NLRP9': 1,
#  'NMBR': 1,
#  'NOTUM': 1,
#  'NPNT': 1,
#  'NPTX2': 1,
#  'NRG3': 1,
#  'NRSN2': 1,
#  'NT5C1A': 1,
#  'NT5C1B': 1,
#  'NT5C1B-RDH14': 1,
#  'NTSR2': 1,
#  'NUGGC': 1,
#  'NXPE4': 1,
#  'NXPH1': 1,
#  'NXPH2': 1,
#  'OFCC1': 1,
#  'OGFRL1': 1,
#  'OLFML2A': 1,
#  'ONECUT3': 1,
#  'OR10G3': 1,
#  'OR10J1': 1,
#  'OR14I1': 1,
#  'OR1D2': 1,
#  'OR1E2': 1,
#  'OR1M1': 1,
#  'OR2AG1': 1,
#  'OR2L13': 1,
#  'OR2T35': 1,
#  'OR3A1': 1,
#  'OR4C12': 1,
#  'OR4D6': 1,
#  'OR51B4': 1,
#  'OR5A1': 1,
#  'OR6B3': 1,
#  'OR6X1': 1,
#  'OR7G3': 1,
#  'OR8B2': 1,
#  'OR8D4': 1,
#  'OR8H2': 1,
#  'OR8K5': 1,
#  'OSCAR': 1,
#  'OTOF': 1,
#  'OTOG': 1,
#  'OTOP2': 1,
#  'OTUD3': 1,
#  'P2RX1': 1,
#  'P2RX3': 1,
#  'P2RX5': 1,
#  'P2RY11': 1,
#  'P2RY12': 1,
#  'P2RY4': 1,
#  'P2RY8': 1,
#  'PAGE5': 1,
#  'PALMD': 1,
#  'PAMR1': 1,
#  'PANX2': 1,
#  'PANX3': 1,
#  'PASD1': 1,
#  'PATE3': 1,
#  'PCDH20': 1,
#  'PCP4L1': 1,
#  'PCSK1N': 1,
#  'PDCD1LG2': 1,
#  'PDDC1': 1,
#  'PDPN': 1,
#  'PDYN': 1,
#  'PDZD4': 1,
#  'PDZK1': 1,
#  'PDZK1IP1': 1,
#  'PET117': 1,
#  'PGBD3': 1,
#  'PGLYRP1': 1,
#  'PGPEP1': 1,
#  'PGPEP1L': 1,
#  'PHF23': 1,
#  'PHLDA2': 1,
#  'PHOSPHO2': 1,
#  'PHTF1': 1,
#  'PIEZO2': 1,
#  'PIK3IP1': 1,
#  'PION': 1,
#  'PLA1A': 1,
#  'PLAC1': 1,
#  'PLB1': 1,
#  'PLCXD2': 1,
#  'PLEKHA3': 1,
#  'PLEKHA6': 1,
#  'PLEKHD1': 1,
#  'PLEKHH3': 1,
#  'PLEKHO2': 1,
#  'PLVAP': 1,
#  'PLXNC1': 1,
#  'PNLIPRP3': 1,
#  'PNMA3': 1,
#  'PNMA6A': 1,
#  'PNOC': 1,
#  'POPDC3': 1,
#  'PORCN': 1,
#  'PPDPF': 1,
#  'PPP1R10': 1,
#  'PPP1R1A': 1,
#  'PPP1R32': 1,
#  'PPP1R35': 1,
#  'PPP1R36': 1,
#  'PQLC3': 1,
#  'PRAMEF1': 1,
#  'PRAMEF10': 1,
#  'PRAMEF12': 1,
#  'PRAMEF13': 1,
#  'PRAMEF14': 1,
#  'PRAMEF16': 1,
#  'PRAMEF17': 1,
#  'PRAMEF2': 1,
#  'PRAMEF6': 1,
#  'PRB4': 1,
#  'PRDM7': 1,
#  'PRG4': 1,
#  'PRH1': 1,
#  'PRIMA1': 1,
#  'PRND': 1,
#  'PROCA1': 1,
#  'PROL1': 1,
#  'PRR15': 1,
#  'PRR19': 1,
#  'PRR20C': 1,
#  'PRR23B': 1,
#  'PRR7': 1,
#  'PRRT4': 1,
#  'PSG1': 1,
#  'PSG2': 1,
#  'PSG5': 1,
#  'PSMG4': 1,
#  'PSORS1C2': 1,
#  'PSTK': 1,
#  'PTAR1': 1,
#  'PTGDR2': 1,
#  'PTPRCAP': 1,
#  'PWWP2A': 1,
#  'PWWP2B': 1,
#  'PYHIN1': 1,
#  'QRFPR': 1,
#  'RAD51AP2': 1,
#  'RAET1E': 1,
#  'RAPGEFL1': 1,
#  'RBM12B-AS1': 1,
#  'RBP7': 1,
#  'RCSD1': 1,
#  'RD3L': 1,
#  'RETN': 1,
#  'RETNLB': 1,
#  'RGL3': 1,
#  'RGMA': 1,
#  'RGS22': 1,
#  'RGS9BP': 1,
#  'RHD': 1,
#  'RNASE11': 1,
#  'RNASE6': 1,
#  'RNASE7': 1,
#  'RNASEK': 1,
#  'RNF157': 1,
#  'RNF222': 1,
#  'ROGDI': 1,
#  'ROPN1B': 1,
#  'RP11-468E2.2': 1,
#  'RP11-77K12.7': 1,
#  'RP13-996F3.4': 1,
#  'RP3-324N14.2': 1,
#  'RP3-377D14.1': 1,
#  'RRNAD1': 1,
#  'RS1': 1,
#  'RTKN2': 1,
#  'RTP2': 1,
#  'RTTN': 1,
#  'RUNDC1': 1,
#  'S100G': 1,
#  'S100Z': 1,
#  'SAMD8': 1,
#  'SAMD9L': 1,
#  'SAPCD2': 1,
#  'SAYSD1': 1,
#  'SBP1': 1,
#  'SBSN': 1,
#  'SCGB1D1': 1,
#  'SCGB3A1': 1,
#  'SCN3B': 1,
#  'SCP2D1': 1,
#  'SCRG1': 1,
#  'SEC16B': 1,
#  'SERAC1': 1,
#  'SERINC2': 1,
#  'SETD9': 1,
#  'SEZ6': 1,
#  'SGK196': 1,
#  'SGMS2': 1,
#  'SH3TC2': 1,
#  'SHISA3': 1,
#  'SIGLEC9': 1,
#  'SIRPD': 1,
#  'SKOR2': 1,
#  'SLC10A7': 1,
#  'SLC16A13': 1,
#  'SLC19A1': 1,
#  'SLC22A17': 1,
#  'SLC22A18AS': 1,
#  'SLC25A30': 1,
#  'SLC25A44': 1,
#  'SLC25A51': 1,
#  'SLC2A4RG': 1,
#  'SLC34A2': 1,
#  'SLC34A3': 1,
#  'SLC35F3': 1,
#  'SLC35G2': 1,
#  'SLC45A1': 1,
#  'SLC45A3': 1,
#  'SLC45A4': 1,
#  'SLC48A1': 1,
#  'SLC51A': 1,
#  'SLCO2A1': 1,
#  'SLCO4A1': 1,
#  'SLCO4C1': 1,
#  'SLFN12': 1,
#  'SLITRK1': 1,
#  'SLITRK4': 1,
#  'SLITRK6': 1,
#  'SMIM2': 1,
#  'SMOC2': 1,
#  'SMPDL3A': 1,
#  'SMPDL3B': 1,
#  'SMPX': 1,
#  'SNN': 1,
#  'SNPH': 1,
#  'SNX21': 1,
#  'SNX31': 1,
#  'SOX17': 1,
#  'SOX21': 1,
#  'SPAG11B': 1,
#  'SPANXB2': 1,
#  'SPANXN4': 1,
#  'SPATA31A3': 1,
#  'SPATA31A7': 1,
#  'SPATA31D1': 1,
#  'SPATA4': 1,
#  'SPATA6': 1,
#  'SPDYE2': 1,
#  'SPEF2': 1,
#  'SPINK13': 1,
#  'SPINK5': 1,
#  'SPINT4': 1,
#  'SPIRE2': 1,
#  'SPRR1B': 1,
#  'SRD5A1': 1,
#  'SSUH2': 1,
#  'SSX3': 1,
#  'SSX4B': 1,
#  'ST3GAL1': 1,
#  'ST8SIA5': 1,
#  'ST8SIA6': 1,
#  'STARD10': 1,
#  'STARD4': 1,
#  'STEAP1': 1,
#  'STMN4': 1,
#  'STOX2': 1,
#  'SUSD5': 1,
#  'SV2A': 1,
#  'SYCP1': 1,
#  'SYNDIG1': 1,
#  'SYPL2': 1,
#  'SYT10': 1,
#  'SYT13': 1,
#  'SYT14': 1,
#  'TAAR2': 1,
#  'TAAR6': 1,
#  'TAAR8': 1,
#  'TBC1D24': 1,
#  'TCEAL5': 1,
#  'TCHHL1': 1,
#  'TCTA': 1,
#  'TCTE3': 1,
#  'TCTEX1D1': 1,
#  'TEX14': 1,
#  'TEX9': 1,
#  'TGM4': 1,
#  'TGM6': 1,
#  'TGM7': 1,
#  'TIFAB': 1,
#  'TIMD4': 1,
#  'TLCD1': 1,
#  'TM4SF19': 1,
#  'TM4SF20': 1,
#  'TM6SF1': 1,
#  'TMC5': 1,
#  'TMC7': 1,
#  'TMCO6': 1,
#  'TMEM106A': 1,
#  'TMEM106B': 1,
#  'TMEM107': 1,
#  'TMEM108': 1,
#  'TMEM119': 1,
#  'TMEM120B': 1,
#  'TMEM129': 1,
#  'TMEM132C': 1,
#  'TMEM135': 1,
#  'TMEM141': 1,
#  'TMEM150C': 1,
#  'TMEM161A': 1,
#  'TMEM164': 1,
#  'TMEM169': 1,
#  'TMEM176B': 1,
#  'TMEM18': 1,
#  'TMEM182': 1,
#  'TMEM185B': 1,
#  'TMEM203': 1,
#  'TMEM204': 1,
#  'TMEM206': 1,
#  'TMEM216': 1,
#  'TMEM225': 1,
#  'TMEM229B': 1,
#  'TMEM233': 1,
#  'TMEM237': 1,
#  'TMEM241': 1,
#  'TMEM252': 1,
#  'TMEM27': 1,
#  'TMEM45A': 1,
#  'TMEM5': 1,
#  'TMEM52B': 1,
#  'TMEM60': 1,
#  'TMEM74': 1,
#  'TMEM74B': 1,
#  'TMIGD2': 1,
#  'TMTC2': 1,
#  'TNFSF18': 1,
#  'TNMD': 1,
#  'TOPAZ1': 1,
#  'TP53INP2': 1,
#  'TP53TG3': 1,
#  'TRABD2A': 1,
#  'TREM2': 1,
#  'TRIM16L': 1,
#  'TRIQK': 1,
#  'TRPV3': 1,
#  'TSHZ1': 1,
#  'TSPAN13': 1,
#  'TSPAN2': 1,
#  'TSPAN31': 1,
#  'TTC17': 1,
#  'TTC21B': 1,
#  'TTC26': 1,
#  ...}
